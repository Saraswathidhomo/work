# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv("studentmark.csv")

# %%
ds
# Out:
#         Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M    5/4/1988     55       45         56       87       21
# 1     Suresh      M    4/5/1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F   12/8/1990     78       96         86       63       54
# 4   Jennifer      F    2/9/1989     58       96         78       46       96
# 5       Annu      F    5/4/1988     45       87         52       89       55
# 6      pooja      F    4/5/1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F   12/8/1990     55       63         89       75       78
# 9     Mukesh      M    2/9/1989     96       46         77       83       58
# 10  Jennifer      F    2/9/1989     58       96         78       46       96
#
#     Economics  History  Civics
# ...

# %%
ds.rename(columns={'Name: 0': 'S Name'},inplace=True)

# %%
ds
# Out:
#         Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M    5/4/1988     55       45         56       87       21
# 1     Suresh      M    4/5/1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F   12/8/1990     78       96         86       63       54
# 4   Jennifer      F    2/9/1989     58       96         78       46       96
# 5       Annu      F    5/4/1988     45       87         52       89       55
# 6      pooja      F    4/5/1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F   12/8/1990     55       63         89       75       78
# 9     Mukesh      M    2/9/1989     96       46         77       83       58
# 10  Jennifer      F    2/9/1989     58       96         78       46       96
#
#     Economics  History  Civics
# ...

# %%
ds.shape
# Out:
# (10, 11)

# %%
ds.tail(3)
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 7  Ritesh      M  25-05-1989     54       76         87       56       25
# 8   Farha      F   12/8/1990     55       63         89       75       78
# 9  Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
ds.sample(5)
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0    John      M    5/4/1988     55       45         56       87       21
# 6   pooja      F    4/5/1987     55       64         61       58       75
# 2  Ramesh      M  25-05-1989     25       54         89       76       95
# 1  Suresh      M    4/5/1987     75       96         78       64       90
# 7  Ritesh      M  25-05-1989     54       76         87       56       25
#
#    Economics  History  Civics
# 0         52       89      65
# 6         58       64      61
# 2         87       56      74
# 1         61       58       2
# 7         56       76      87

# %%
ds.iloc[:,3:5]
# Out:
#    Maths  Physics
# 0     55       45
# 1     75       96
# 2     25       54
# 3     78       96
# 4     58       96
# 5     45       87
# 6     55       64
# 7     54       76
# 8     55       63
# 9     96       46

# %%
ds.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %%
ds.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %%
ds
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
ds['Name'][2]
# Out:
# 'Ramesh'

# %%
ds['Name'][2]='Ram'

# %%
ds
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2       Ram      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
ds['Name'][2]=np.nan

# %%
ds
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2       NaN      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
ds.isnull()
# Out:
#     Name  Gender    DOB  Maths  Physics  Chemistry  English  Biology  \
# 0  False   False  False  False    False      False    False    False
# 1  False   False  False  False    False      False    False    False
# 2   True   False  False  False    False      False    False    False
# 3  False   False  False  False    False      False    False    False
# 4  False   False  False  False    False      False    False    False
# 5  False   False  False  False    False      False    False    False
# 6  False   False  False  False    False      False    False    False
# 7  False   False  False  False    False      False    False    False
# 8  False   False  False  False    False      False    False    False
# 9  False   False  False  False    False      False    False    False
#
#    Economics  History  Civics
# 0      False    False   False
# 1      False    False   False
# 2      False    False   False
# 3      False    False   False
# 4      False    False   False
# ...

# %%
ds.isnull().sum()
# Out:
# Name         1
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %%
ds.dtypes
# Out:
# Name         object
# Gender       object
# DOB          object
# Maths         int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
ds['Gender'].value_counts()
# Out:
# Gender
# M    5
# F    5
# Name: count, dtype: int64

# %%
ds.nunique()
# Out:
# Name          9
# Gender        2
# DOB           5
# Maths         8
# Physics       8
# Chemistry     8
# English      10
# Biology      10
# Economics     9
# History      10
# Civics       10
# dtype: int64

# %%
ds
# Out:
#         Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M    5/4/1988     55       45         56       87       21
# 1     Suresh      M    4/5/1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F   12/8/1990     78       96         86       63       54
# 4   Jennifer      F    2/9/1989     58       96         78       46       96
# 5       Annu      F    5/4/1988     45       87         52       89       55
# 6      pooja      F    4/5/1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F   12/8/1990     55       63         89       75       78
# 9     Mukesh      M    2/9/1989     96       46         77       83       58
# 10  Jennifer      F    2/9/1989     58       96         78       46       96
#
#     Economics  History  Civics
# ...

# %%
ds[ds.duplicated()]
# Out:
#         Name Gender       DOB  Maths  Physics  Chemistry  English  Biology  \
# 10  Jennifer      F  2/9/1989     58       96         78       46       96
#
#     Economics  History  Civics
# 10         77       83      53

# %%
ds.drop_duplicates(inplace=True)

# %%
ds
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
ds.count()
# Out:
# Name         10
# Gender       10
# DOB          10
# Maths        10
# Physics      10
# Chemistry    10
# English      10
# Biology      10
# Economics    10
# History      10
# Civics       10
# dtype: int64

# %%
ds['Maths'].count()
# Out:
# 10

# %%
ds
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
ds.rename(columns={'DOB':'Date_Of_Birth'},inplace=True)

# %%
ds
# Out:
#        Name Gender Date_Of_Birth  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M      5/4/1988     55       45         56       87       21
# 1    Suresh      M      4/5/1987     75       96         78       64       90
# 2    Ramesh      M    25-05-1989     25       54         89       76       95
# 3   Jessica      F     12/8/1990     78       96         86       63       54
# 4  Jennifer      F      2/9/1989     58       96         78       46       96
# 5      Annu      F      5/4/1988     45       87         52       89       55
# 6     pooja      F      4/5/1987     55       64         61       58       75
# 7    Ritesh      M    25-05-1989     54       76         87       56       25
# 8     Farha      F     12/8/1990     55       63         89       75       78
# 9    Mukesh      M      2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
ds.rename(columns={'Name':'SName'},inplace=True)

# %%
ds
# Out:
#       SName Gender Date_Of_Birth  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M      5/4/1988     55       45         56       87       21
# 1    Suresh      M      4/5/1987     75       96         78       64       90
# 2    Ramesh      M    25-05-1989     25       54         89       76       95
# 3   Jessica      F     12/8/1990     78       96         86       63       54
# 4  Jennifer      F      2/9/1989     58       96         78       46       96
# 5      Annu      F      5/4/1988     45       87         52       89       55
# 6     pooja      F      4/5/1987     55       64         61       58       75
# 7    Ritesh      M    25-05-1989     54       76         87       56       25
# 8     Farha      F     12/8/1990     55       63         89       75       78
# 9    Mukesh      M      2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
ds.dropna(inplace=True)

# %%
ds
# Out:
#       SName Gender Date_Of_Birth  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M      5/4/1988     55       45         56       87       21
# 1    Suresh      M      4/5/1987     75       96         78       64       90
# 2    Ramesh      M    25-05-1989     25       54         89       76       95
# 3   Jessica      F     12/8/1990     78       96         86       63       54
# 4  Jennifer      F      2/9/1989     58       96         78       46       96
# 5      Annu      F      5/4/1988     45       87         52       89       55
# 6     pooja      F      4/5/1987     55       64         61       58       75
# 7    Ritesh      M    25-05-1989     54       76         87       56       25
# 8     Farha      F     12/8/1990     55       63         89       75       78
# 9    Mukesh      M      2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
ds.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
ds.describe(include='all')
# Out:
#        SName Gender Date_Of_Birth      Maths    Physics  Chemistry    English  \
# count     10     10            10  10.000000  10.000000  10.000000  10.000000
# unique    10      2             5        NaN        NaN        NaN        NaN
# top     John      M      5/4/1988        NaN        NaN        NaN        NaN
# freq       1      5             2        NaN        NaN        NaN        NaN
# mean     NaN    NaN           NaN  59.600000  72.300000  75.300000  69.700000
# std      NaN    NaN           NaN  19.460501  20.661559  14.000397  14.453373
# min      NaN    NaN           NaN  25.000000  45.000000  52.000000  46.000000
# 25%      NaN    NaN           NaN  54.250000  56.250000  65.000000  59.250000
# 50%      NaN    NaN           NaN  55.000000  70.000000  78.000000  69.500000
# 75%      NaN    NaN           NaN  70.750000  93.750000  86.750000  81.250000
# max      NaN    NaN           NaN  96.000000  96.000000  89.000000  89.000000
#
# ...

# %%
ds.drop([8,9],axis=0,inplace=True)

# %%
ds
# Out:
#       SName Gender Date_Of_Birth  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M      5/4/1988     55       45         56       87       21
# 1    Suresh      M      4/5/1987     75       96         78       64       90
# 2    Ramesh      M    25-05-1989     25       54         89       76       95
# 3   Jessica      F     12/8/1990     78       96         86       63       54
# 4  Jennifer      F      2/9/1989     58       96         78       46       96
# 5      Annu      F      5/4/1988     45       87         52       89       55
# 6     pooja      F      4/5/1987     55       64         61       58       75
# 7    Ritesh      M    25-05-1989     54       76         87       56       25
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53
# 5         89       87      52
# 6         58       64      61
# ...

# %%
ds.drop('Date_Of_Birth',axis=1,inplace=True)

# %%
ds
# Out:
#       SName Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0      John      M     55       45         56       87       21         52
# 1    Suresh      M     75       96         78       64       90         61
# 2    Ramesh      M     25       54         89       76       95         87
# 3   Jessica      F     78       96         86       63       54         89
# 4  Jennifer      F     58       96         78       46       96         77
# 5      Annu      F     45       87         52       89       55         89
# 6     pooja      F     55       64         61       58       75         58
# 7    Ritesh      M     54       76         87       56       25         56
#
#    History  Civics
# 0       89      65
# 1       58       2
# 2       56      74
# 3       75      45
# 4       83      53
# 5       87      52
# 6       64      61
# 7       76      87

# %%
ds
# Out:
#       SName Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0      John      M     55       45         56       87       21         52
# 1    Suresh      M     75       96         78       64       90         61
# 2    Ramesh      M     25       54         89       76       95         87
# 3   Jessica      F     78       96         86       63       54         89
# 4  Jennifer      F     58       96         78       46       96         77
# 5      Annu      F     45       87         52       89       55         89
# 6     pooja      F     55       64         61       58       75         58
# 7    Ritesh      M     54       76         87       56       25         56
#
#    Civics
# 0      65
# 1       2
# 2      74
# 3      45
# 4      53
# 5      52
# 6      61
# 7      87

# %%
ds.drop(['Economics','Civics'],axis=1,inplace=True)

# %%
ds
# Out:
#       SName Gender  Maths  Physics  Chemistry  English  Biology
# 0      John      M     55       45         56       87       21
# 1    Suresh      M     75       96         78       64       90
# 2    Ramesh      M     25       54         89       76       95
# 3   Jessica      F     78       96         86       63       54
# 4  Jennifer      F     58       96         78       46       96
# 5      Annu      F     45       87         52       89       55
# 6     pooja      F     55       64         61       58       75
# 7    Ritesh      M     54       76         87       56       25
